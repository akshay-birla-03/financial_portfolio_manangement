# %% [markdown]
# # Financial Portfolio Management — one-click run
# Loads the pre-optimised portfolio and (optionally) launches the full Streamlit dashboard.
# Press **Runtime → Run all**.

# %%
# !git clone https://github.com/akshay-birla-03/financial_portfolio_manangement.git
# %cd financial_portfolio_manangement

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ### Inspect the optimised portfolio (headless, instant)

# %%
import joblib
portfolio = joblib.load('models/optimized_portfolio.joblib')
print(type(portfolio))
portfolio

# %% [markdown]
# ### (Optional) launch the interactive Streamlit dashboard
# This starts the app and prints a public URL via a tunnel. Click the link that appears.

# %%
# !pip install -q streamlit
# !curl -s https://loca.lt/mytunnelpassword 2>/dev/null || true
# !streamlit run app.py &>/content/logs.txt & npx --yes localtunnel --port 8501
